# %% [markdown]
# Loading tensorflow and keras and other appropriate libraries:

# %%
from tensorflow import keras

import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# Loading Cifar-10 dataset from keras datasets and separate test and train datas:

# %%
(train_images, train_labels), (test_images, test_labels)= keras.datasets.cifar10.load_data()

# %% [markdown]
# Define the class names of the dataset labels:

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# # Investigate on dataset

# %% [markdown]
# Plot the first 20 images along with their labels:

# %%
plt.figure(figsize=(10,10))
for i in range(0,20):
    plt.subplot(5,5, i+1)
    plt.imshow(train_images[i])
    plt.title(class_names[(train_labels[i][0])])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# Printing the shape of the train and test images:

# %%
print("train_images", train_images.shape)
print("test_images", test_images.shape)
# Out:
# train_images (50000, 32, 32, 3)
# test_images (10000, 32, 32, 3)

# %% [markdown]
# Plot an image figure of the train images for better illustration:

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)

# %% [markdown]
# Scaling the images of the dataset to a range of 0 to 1:

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# # Importing appropriate tools for modeling our neural network:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, Dropout, BatchNormalization, AveragePooling2D
from tensorflow.keras import regularizers

# %% [markdown]
# # Modeling a convolutional neural network:

# %% [markdown]
# ## model 1

# %%
model1 = Sequential()
# zero padding
model1.add(Conv2D(32,(5,5), padding="same", input_shape=(32,32,3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Conv2D(32,(5,5), padding="same", input_shape=(32,32,3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Flatten())

model1.add(Dense(128, activation='relu'))
model1.add(Dense(64, activation='relu'))

model1.add(Dense(10, activation='softmax'))

model1.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 32)        25632
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               262272
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model1.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model 2

# %%
model2 = Sequential()
# zero padding
model2.add(Conv2D(32,(5,5), padding="same", input_shape=(32,32,3), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Conv2D(32,(5,5), padding="same", input_shape=(32,32,3), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Flatten())

model2.add(Dense(64, activation='relu'))
model2.add(Dense(64, activation='relu'))

model2.add(Dense(10, activation='softmax'))

model2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_10 (Conv2D)           (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 32)        25632
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                131136
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                4160
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model2.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model 3

# %%
model3 = Sequential()
# zero padding
model3.add(Conv2D(32,(5,5), padding="same", input_shape=(32,32,3), activation='relu'))
model3.add(MaxPooling2D(pool_size=(2,2)))

model3.add(Conv2D(32,(5,5), padding="same", input_shape=(32,32,3), activation='relu'))
model3.add(MaxPooling2D(pool_size=(2,2)))

model3.add(Flatten())


model3.add(Dense(10, activation='softmax'))

model3.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        2432
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 32)        25632
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                20490
# ...
# Total params: 48,554
# Trainable params: 48,554
# Non-trainable params: 0
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model3.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model 4

# %%
model4 = Sequential()
# zero padding
model4.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu'))
model4.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu'))
model4.add(MaxPooling2D(pool_size=(2,2)))

model4.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu'))
model4.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu'))
model4.add(MaxPooling2D(pool_size=(2,2)))

model4.add(Flatten())


model4.add(Dense(10, activation='softmax'))

model4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model4.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model 5

# %%
model5 = Sequential()
# zero padding
model5.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu'))
model5.add(Conv2D(32,(3,3), padding="same", activation='relu'))
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Conv2D(64,(3,3), padding="same", activation='relu'))
model5.add(Conv2D(64,(3,3), padding="same", activation='relu'))
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Conv2D(128,(3,3), padding="same", activation='relu'))
model5.add(Conv2D(128,(3,3), padding="same", activation='relu'))
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Conv2D(256,(3,3), padding="same", activation='relu'))
model5.add(Conv2D(256,(3,3), padding="same", activation='relu'))
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Flatten())


model5.add(Dense(10, activation='softmax'))

model5.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 128)         73856
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model5.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model 5_1

# %%
model5_1 = Sequential()
# zero padding
model5_1.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu'))
model5_1.add(Conv2D(32,(3,3), padding="same", activation='relu'))
model5_1.add(AveragePooling2D(pool_size=(2,2)))

model5_1.add(Conv2D(64,(3,3), padding="same", activation='relu'))
model5_1.add(Conv2D(64,(3,3), padding="same", activation='relu'))
model5_1.add(AveragePooling2D(pool_size=(2,2)))

model5_1.add(Conv2D(128,(3,3), padding="same", activation='relu'))
model5_1.add(Conv2D(128,(3,3), padding="same", activation='relu'))
model5_1.add(AveragePooling2D(pool_size=(2,2)))

model5_1.add(Conv2D(256,(3,3), padding="same", activation='relu'))
model5_1.add(Conv2D(256,(3,3), padding="same", activation='relu'))
model5_1.add(AveragePooling2D(pool_size=(2,2)))

model5_1.add(Flatten())


model5_1.add(Dense(10, activation='softmax'))

model5_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model5_1.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model 6

# %%
model6 = Sequential()
# zero padding
model6.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu'))
model6.add(Conv2D(32,(3,3), padding="same", activation='relu'))
model6.add(MaxPooling2D(pool_size=(2,2)))
model6.add(Dropout(0.1))

model6.add(Conv2D(64,(3,3), padding="same", activation='relu'))
model6.add(Conv2D(64,(3,3), padding="same", activation='relu'))
model6.add(MaxPooling2D(pool_size=(2,2)))
model6.add(Dropout(0.2))

model6.add(Conv2D(128,(3,3), padding="same", activation='relu'))
model6.add(Conv2D(128,(3,3), padding="same", activation='relu'))
model6.add(MaxPooling2D(pool_size=(2,2)))
model6.add(Dropout(0.3))

model6.add(Conv2D(256,(3,3), padding="same", activation='relu'))
model6.add(Conv2D(256,(3,3), padding="same", activation='relu'))
model6.add(MaxPooling2D(pool_size=(2,2)))
model6.add(Dropout(0.4))

model6.add(Flatten())


model6.add(Dense(10, activation='softmax'))

model6.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_16 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 8, 8, 64)          0
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model6.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model 7

# %%
model7 = Sequential()
# zero padding
model7.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu'))
model7.add(BatchNormalization())
model7.add(Conv2D(32,(3,3), padding="same", activation='relu'))
model7.add(BatchNormalization())
model7.add(MaxPooling2D(pool_size=(2,2)))
model7.add(Dropout(0.1))

model7.add(Conv2D(64,(3,3), padding="same", activation='relu'))
model7.add(BatchNormalization())
model7.add(Conv2D(64,(3,3), padding="same", activation='relu'))
model7.add(BatchNormalization())
model7.add(MaxPooling2D(pool_size=(2,2)))
model7.add(Dropout(0.2))

model7.add(Conv2D(128,(3,3), padding="same", activation='relu'))
model7.add(BatchNormalization())
model7.add(Conv2D(128,(3,3), padding="same", activation='relu'))
model7.add(BatchNormalization())
model7.add(MaxPooling2D(pool_size=(2,2)))
model7.add(Dropout(0.3))

model7.add(Conv2D(256,(3,3), padding="same", activation='relu'))
model7.add(BatchNormalization())
model7.add(Conv2D(256,(3,3), padding="same", activation='relu'))
model7.add(BatchNormalization())
model7.add(MaxPooling2D(pool_size=(2,2)))
model7.add(Dropout(0.4))

model7.add(Flatten())


model7.add(Dense(10, activation='softmax'))

model7.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_25 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 16, 16, 64)        18496
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model7.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model 8

# %%
model8 = Sequential()
# zero padding
model8.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model8.add(BatchNormalization())
model8.add(Conv2D(32,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model8.add(BatchNormalization())
model8.add(MaxPooling2D(pool_size=(2,2)))
model8.add(Dropout(0.1))

model8.add(Conv2D(64,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model8.add(BatchNormalization())
model8.add(Conv2D(64,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model8.add(BatchNormalization())
model8.add(MaxPooling2D(pool_size=(2,2)))
model8.add(Dropout(0.2))

model8.add(Conv2D(128,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model8.add(BatchNormalization())
model8.add(Conv2D(128,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model8.add(BatchNormalization())
model8.add(MaxPooling2D(pool_size=(2,2)))
model8.add(Dropout(0.3))

model8.add(Conv2D(256,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model8.add(BatchNormalization())
model8.add(Conv2D(256,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
model8.add(BatchNormalization())
model8.add(MaxPooling2D(pool_size=(2,2)))
model8.add(Dropout(0.4))

model8.add(Flatten())


model8.add(Dense(10, activation='softmax'))

model8.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_34 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 16, 16, 64)        18496
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model8.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model 9

# %%
model9 = Sequential()
# zero padding
model9.add(Conv2D(32,(3,3), padding="same", input_shape=(32,32,3), activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
model9.add(BatchNormalization())
model9.add(Conv2D(32,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
model9.add(BatchNormalization())
model9.add(MaxPooling2D(pool_size=(2,2)))
model9.add(Dropout(0.1))

model9.add(Conv2D(64,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
model9.add(BatchNormalization())
model9.add(Conv2D(64,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
model9.add(BatchNormalization())
model9.add(MaxPooling2D(pool_size=(2,2)))
model9.add(Dropout(0.2))

model9.add(Conv2D(128,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
model9.add(BatchNormalization())
model9.add(Conv2D(128,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
model9.add(BatchNormalization())
model9.add(MaxPooling2D(pool_size=(2,2)))
model9.add(Dropout(0.3))

model9.add(Conv2D(256,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
model9.add(BatchNormalization())
model9.add(Conv2D(256,(3,3), padding="same", activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
model9.add(BatchNormalization())
model9.add(MaxPooling2D(pool_size=(2,2)))
model9.add(Dropout(0.4))

model9.add(Flatten())


model9.add(Dense(10, activation='softmax'))

model9.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_40 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 16, 16, 64)        18496
# ...

# %% [markdown]
# Compile the model:

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model9.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# the labels aren't encoded instead they are sparse : 1 2 3 ...
# multiclass
model9.compile(optimizer='SGD',loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## model

# %%
model = Sequential()
# same = zero padding
model.add(Conv2D(32,(3,3),padding="same",input_shape=(32,32,3),activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
model.add(BatchNormalization())
model.add(Conv2D(32,(3,3),padding="same",activation='relu',kernel_regularizer=regularizers.l2(1e-3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(64,(3,3),padding="same",activation='relu',kernel_regularizer=regularizers.l2(1e-3)))
model.add(BatchNormalization())
model.add(Conv2D(64,(3,3),padding="same",activation='relu',kernel_regularizer=regularizers.l2(1e-3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(128,(3,3),padding="same",activation='relu',kernel_regularizer=regularizers.l2(1e-3)))
model.add(BatchNormalization())
model.add(Conv2D(128,(3,3),padding="same",activation='relu',kernel_regularizer=regularizers.l2(1e-3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(256,(3,3),padding="same",activation='relu',kernel_regularizer=regularizers.l2(1e-3)))
model.add(BatchNormalization())
model.add(Conv2D(256,(3,3),padding="same",activation='relu',kernel_regularizer=regularizers.l2(1e-3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

# convert matrix to vector for fully connected
model.add(Flatten())
# fully connected
# model.add(Dense(128,activation='relu'))
# model.add(Dense(64,activation='relu'))
# output layer
model.add(Dense(10,activation='softmax'))
model.summary()

# %% [markdown]
# Compile the model:

# %%
model.compile(optimizer='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Training the model by fitting it to the train data:

# %%
def train_model_evaluate(model, epochs, validation_split=0.2, callbacks=None):
  history = model.fit(train_images, train_labels, epochs=epochs, validation_split=validation_split, callbacks=callbacks)
  # Evaluate the model with the test data:
  test_loss, test_accuracy = model.evaluate(test_images, test_labels)
  print( ' %.3f' % (test_loss), ' %.3f' % (test_accuracy * 100.0))
  # Loss plot for model
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title("Loss")
  plt.ylabel("loss")
  plt.xlabel("epoch")
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # Accuracy plot
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title("Accuracy")
  plt.ylabel("accuracy")
  plt.xlabel("epoch")
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %% [markdown]
# Early stopping callback:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=20)

# %% [markdown]
# ## train model 1

# %%
train_model_evaluate(model1, 20)
# Out:
# Epoch 1/20
# 1250/1250 [==============================] - 5s 3ms/step - loss: 1.9527 - accuracy: 0.2898 - val_loss: 1.7758 - val_accuracy: 0.3605
# Epoch 2/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.5741 - accuracy: 0.4337 - val_loss: 1.5267 - val_accuracy: 0.4607
# Epoch 3/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.4254 - accuracy: 0.4875 - val_loss: 1.4113 - val_accuracy: 0.5000
# Epoch 4/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.3168 - accuracy: 0.5308 - val_loss: 1.3318 - val_accuracy: 0.5245
# Epoch 5/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.2215 - accuracy: 0.5677 - val_loss: 1.2270 - val_accuracy: 0.5689
# Epoch 6/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.1412 - accuracy: 0.5948 - val_loss: 1.1756 - val_accuracy: 0.5877
# Epoch 7/20
# ...

# %% [markdown]
# ## train model 2

# %%
train_model_evaluate(model2, 50)
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.0030 - accuracy: 0.2678 - val_loss: 1.7716 - val_accuracy: 0.3754
# Epoch 2/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.6427 - accuracy: 0.4095 - val_loss: 1.5296 - val_accuracy: 0.4449
# Epoch 3/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.4788 - accuracy: 0.4665 - val_loss: 1.4343 - val_accuracy: 0.4851
# Epoch 4/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.3672 - accuracy: 0.5084 - val_loss: 1.3327 - val_accuracy: 0.5254
# Epoch 5/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.2802 - accuracy: 0.5424 - val_loss: 1.3152 - val_accuracy: 0.5292
# Epoch 6/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.1965 - accuracy: 0.5721 - val_loss: 1.2137 - val_accuracy: 0.5688
# Epoch 7/50
# ...

# %% [markdown]
# ## train model 3

# %%
train_model_evaluate(model3, 50)
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.9518 - accuracy: 0.2966 - val_loss: 1.6852 - val_accuracy: 0.4082
# Epoch 2/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.6058 - accuracy: 0.4308 - val_loss: 1.5320 - val_accuracy: 0.4638
# Epoch 3/50
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.4749 - accuracy: 0.4736 - val_loss: 1.4093 - val_accuracy: 0.5045
# Epoch 4/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.3733 - accuracy: 0.5156 - val_loss: 1.3618 - val_accuracy: 0.5253
# Epoch 5/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.2907 - accuracy: 0.5452 - val_loss: 1.3051 - val_accuracy: 0.5389
# Epoch 6/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.2201 - accuracy: 0.5724 - val_loss: 1.2348 - val_accuracy: 0.5720
# Epoch 7/50
# ...

# %% [markdown]
# ## train model 4

# %%
train_model_evaluate(model4, 200, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 14s 11ms/step - loss: 2.0588 - accuracy: 0.2573 - val_loss: 1.8553 - val_accuracy: 0.3350
# Epoch 2/200
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.6803 - accuracy: 0.4038 - val_loss: 1.5686 - val_accuracy: 0.4351
# Epoch 3/200
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.4848 - accuracy: 0.4721 - val_loss: 1.4465 - val_accuracy: 0.4826
# Epoch 4/200
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.3512 - accuracy: 0.5188 - val_loss: 1.2951 - val_accuracy: 0.5422
# Epoch 5/200
# 1250/1250 [==============================] - 13s 10ms/step - loss: 1.2516 - accuracy: 0.5562 - val_loss: 1.2516 - val_accuracy: 0.5567
# Epoch 6/200
# 1250/1250 [==============================] - 12s 10ms/step - loss: 1.1799 - accuracy: 0.5792 - val_loss: 1.1787 - val_accuracy: 0.5827
# Epoch 7/200
# ...

# %% [markdown]
# ## train model 5

# %%
train_model_evaluate(model5, 200, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 26s 20ms/step - loss: 2.2112 - accuracy: 0.1682 - val_loss: 2.0756 - val_accuracy: 0.2526
# Epoch 2/200
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.8760 - accuracy: 0.3196 - val_loss: 1.6908 - val_accuracy: 0.3896
# Epoch 3/200
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.6297 - accuracy: 0.4157 - val_loss: 1.5250 - val_accuracy: 0.4509
# Epoch 4/200
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.4677 - accuracy: 0.4754 - val_loss: 1.4876 - val_accuracy: 0.4800
# Epoch 5/200
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.3590 - accuracy: 0.5166 - val_loss: 1.3065 - val_accuracy: 0.5435
# Epoch 6/200
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.2561 - accuracy: 0.5576 - val_loss: 1.2416 - val_accuracy: 0.5620
# Epoch 7/200
# ...

# %% [markdown]
# ## train model 5_1

# %%
train_model_evaluate(model5_1, 200, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 39s 6ms/step - loss: 2.2860 - accuracy: 0.1312 - val_loss: 2.1823 - val_accuracy: 0.2009
# Epoch 2/200
# 1250/1250 [==============================] - 7s 6ms/step - loss: 2.0536 - accuracy: 0.2459 - val_loss: 1.9697 - val_accuracy: 0.2796
# Epoch 3/200
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.9216 - accuracy: 0.2921 - val_loss: 1.8804 - val_accuracy: 0.3213
# Epoch 4/200
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.7687 - accuracy: 0.3622 - val_loss: 1.7399 - val_accuracy: 0.3738
# Epoch 5/200
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.6463 - accuracy: 0.4104 - val_loss: 1.5821 - val_accuracy: 0.4333
# Epoch 6/200
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.5590 - accuracy: 0.4416 - val_loss: 1.5247 - val_accuracy: 0.4548
# Epoch 7/200
# ...

# %%
# cannot easily visualize filters lower down
# from keras.applications.vgg16 import VGG16
from matplotlib import pyplot
# # load the model
# model = VGG16()
# retrieve weights from the second hidden layer
for k in range(len(model5_1.layers)):
  if 'conv' not in model5_1.layers[k].name:
    continue
  if len(model5_1.layers[k].get_weights()) == 0:
    continue
  filters, biases = model5_1.layers[k].get_weights()
  # normalize filter values to 0-1 so we can visualize them
  f_min, f_max = filters.min(), filters.max()
  filters = (filters - f_min) / (f_max - f_min)
  # plot first few filters
  n_filters, ix = 6, 1
  for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    # plot each channel separately
    for j in range(3):
      # specify subplot and turn of axis
      ax = pyplot.subplot(n_filters, 3, ix)
      ax.set_xticks([])
      ax.set_yticks([])
      # plot filter channel in grayscale
      pyplot.imshow(f[:, :, j], cmap='gray')
      ix += 1
  # show the figure
  print(model5_1.layers[k].name)
  pyplot.show()
# Out:
# conv2d
# conv2d_1
# conv2d_2
# conv2d_3
# conv2d_4
# conv2d_5
# conv2d_6
# conv2d_7

# %% [markdown]
# ## train model 6

# %%
train_model_evaluate(model6, 200, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 27s 21ms/step - loss: 2.2365 - accuracy: 0.1528 - val_loss: 2.1648 - val_accuracy: 0.1954
# Epoch 2/200
# 1250/1250 [==============================] - 26s 21ms/step - loss: 2.0032 - accuracy: 0.2559 - val_loss: 1.8876 - val_accuracy: 0.2998
# Epoch 3/200
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.8150 - accuracy: 0.3242 - val_loss: 1.7215 - val_accuracy: 0.3735
# Epoch 4/200
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.6912 - accuracy: 0.3731 - val_loss: 1.5829 - val_accuracy: 0.4159
# Epoch 5/200
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.5936 - accuracy: 0.4098 - val_loss: 1.4706 - val_accuracy: 0.4565
# Epoch 6/200
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.5064 - accuracy: 0.4457 - val_loss: 1.4957 - val_accuracy: 0.4477
# Epoch 7/200
# ...

# %% [markdown]
# ## train model 7

# %%
train_model_evaluate(model7, 200, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 101s 26ms/step - loss: 2.0834 - accuracy: 0.3885 - val_loss: 1.5573 - val_accuracy: 0.4671
# Epoch 2/200
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.3636 - accuracy: 0.5442 - val_loss: 1.2698 - val_accuracy: 0.5689
# Epoch 3/200
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.1180 - accuracy: 0.6176 - val_loss: 1.0507 - val_accuracy: 0.6370
# Epoch 4/200
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.9672 - accuracy: 0.6687 - val_loss: 0.8187 - val_accuracy: 0.7108
# Epoch 5/200
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8601 - accuracy: 0.7024 - val_loss: 0.7815 - val_accuracy: 0.7241
# Epoch 6/200
# 1250/1250 [==============================] - 31s 24ms/step - loss: 0.7825 - accuracy: 0.7282 - val_loss: 0.7742 - val_accuracy: 0.7347
# Epoch 7/200
# ...

# %% [markdown]
# ## train model 8

# %%
train_model_evaluate(model8, 200, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 33s 25ms/step - loss: 2.2472 - accuracy: 0.3789 - val_loss: 1.8176 - val_accuracy: 0.4243
# Epoch 2/200
# 1250/1250 [==============================] - 31s 24ms/step - loss: 1.6025 - accuracy: 0.5185 - val_loss: 1.2907 - val_accuracy: 0.5784
# Epoch 3/200
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.2911 - accuracy: 0.5965 - val_loss: 1.0835 - val_accuracy: 0.6589
# Epoch 4/200
# 1250/1250 [==============================] - 31s 24ms/step - loss: 1.1155 - accuracy: 0.6458 - val_loss: 1.0228 - val_accuracy: 0.6706
# Epoch 5/200
# 1250/1250 [==============================] - 31s 25ms/step - loss: 1.0039 - accuracy: 0.6812 - val_loss: 0.9028 - val_accuracy: 0.7123
# Epoch 6/200
# 1250/1250 [==============================] - 32s 26ms/step - loss: 0.9229 - accuracy: 0.7113 - val_loss: 0.8329 - val_accuracy: 0.7361
# Epoch 7/200
# ...

# %% [markdown]
# ## train model 9

# %%
train_model_evaluate(model9, 200, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 42s 7ms/step - loss: 2.8642 - accuracy: 0.3812 - val_loss: 2.2466 - val_accuracy: 0.4864
# Epoch 2/200
# 1250/1250 [==============================] - 9s 7ms/step - loss: 2.1791 - accuracy: 0.5240 - val_loss: 1.8153 - val_accuracy: 0.6307
# Epoch 3/200
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.8846 - accuracy: 0.6115 - val_loss: 1.7639 - val_accuracy: 0.6495
# Epoch 4/200
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.6973 - accuracy: 0.6625 - val_loss: 1.5526 - val_accuracy: 0.7048
# Epoch 5/200
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.5607 - accuracy: 0.7006 - val_loss: 1.5274 - val_accuracy: 0.7064
# Epoch 6/200
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.4581 - accuracy: 0.7277 - val_loss: 1.3750 - val_accuracy: 0.7516
# Epoch 7/200
# ...

# %% [markdown]
# ## train model 10

# %% [markdown]
# data augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2)
# width_shift = 3/32
# height_shift = 3/32
# flip = True

# datagen_train = ImageDataGenerator(
#     horizontal_flip=flip,
#     width_shift_range=width_shift,
#     height_shift_range=height_shift,
#     )
# datagen_train.fit(X_train)

# datagen_val = ImageDataGenerator(
#     horizontal_flip=flip,
#     width_shift_range=width_shift,
#     height_shift_range=height_shift,
#     )
# datagen_val.fit(X_val)
# one hot encode target values
trainY = to_categorical(y_train)
testY = to_categorical(y_val)

# create data generator
datagen_train = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
# prepare iterator
it_train = datagen_train.flow(X_train, trainY, batch_size=64)

# it_train = datagen_train.flow(X_train, y_train, shuffle=False)
# it_val = datagen_val.flow(X_val, y_val, shuffle=False)

# batch_images, batch_labels = next(it)

# %%
steps = int(X_train.shape[0] / 64)	
steps
# Out:
# 625

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
	# plot loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='test')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='test')
	# save plot to file
	# filename = sys.argv[0].split('/')[-1]
	# plt.savefig(filename + '_plot.png')
	plt.show()

# %%
history = model9.fit_generator(it_train, steps_per_epoch=steps, epochs=200, validation_data=(X_val, testY),callbacks=[early_stop])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/200
# 625/625 [==============================] - 22s 34ms/step - loss: 3.0148 - accuracy: 0.3482 - val_loss: 3.2192 - val_accuracy: 0.4539
# Epoch 2/200
# 625/625 [==============================] - 21s 33ms/step - loss: 2.4436 - accuracy: 0.4575 - val_loss: 2.2949 - val_accuracy: 0.4702
# Epoch 3/200
# 625/625 [==============================] - 21s 33ms/step - loss: 2.2317 - accuracy: 0.5185 - val_loss: 2.2470 - val_accuracy: 0.5082
# Epoch 4/200
# 625/625 [==============================] - 21s 33ms/step - loss: 2.1029 - accuracy: 0.5518 - val_loss: 2.1043 - val_accuracy: 0.5666
# Epoch 5/200
# ...

# %%
  test__y = to_categorical(test_labels)
  # Evaluate the model with the test data:
  test_loss, test_accuracy = model9.evaluate(test_images, test__y, verbose=0)
  print( ' %.3f' % (test_loss), ' %.3f' % (test_accuracy * 100.0))
  # Loss plot for model
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title("Loss")
  plt.ylabel("loss")
  plt.xlabel("epoch")
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # Accuracy plot
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title("Accuracy")
  plt.ylabel("accuracy")
  plt.xlabel("epoch")
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
# Out:
#  0.644  86.860

# %% [markdown]
# # visualize kernels in network

# %%
from matplotlib import pyplot
# retrieve weights from the second hidden layer
for k in range(len(model9.layers)):
  if 'conv' not in model9.layers[k].name:
    continue
  if len(model9.layers[k].get_weights()) == 0:
    continue
  filters, biases = model9.layers[k].get_weights()
  # normalize filter values to 0-1 so we can visualize them
  f_min, f_max = filters.min(), filters.max()
  filters = (filters - f_min) / (f_max - f_min)
  # plot first few filters
  n_filters, ix = 6, 1
  for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    # plot each channel separately
    for j in range(3):
      # specify subplot and turn of axis
      ax = pyplot.subplot(n_filters, 3, ix)
      ax.set_xticks([])
      ax.set_yticks([])
      # plot filter channel in grayscale
      pyplot.imshow(f[:, :, j], cmap='gray')
      ix += 1
  # show the figure
  print(model9.layers[k].name,'------------------------------------------------------------------')
  pyplot.show()
# Out:
# conv2d_40 ------------------------------------------------------------------
# conv2d_41 ------------------------------------------------------------------
# conv2d_42 ------------------------------------------------------------------
# conv2d_43 ------------------------------------------------------------------
# conv2d_44 ------------------------------------------------------------------
# conv2d_45 ------------------------------------------------------------------
# conv2d_46 ------------------------------------------------------------------
# conv2d_47 ------------------------------------------------------------------

# %% [markdown]
# #Extracting classification report:

# %%
from sklearn.metrics import classification_report

# %%
predications = model9.predict_classes(test_images)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %% [markdown]
# class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
#                'dog', 'frog', 'horse', 'ship', 'truck']

# %%
print(classification_report(test_labels, predications))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.89      1000
#            1       0.96      0.91      0.93      1000
#            2       0.83      0.82      0.83      1000
#            3       0.81      0.68      0.74      1000
#            4       0.84      0.89      0.86      1000
#            5       0.85      0.78      0.81      1000
#            6       0.76      0.97      0.85      1000
#            7       0.96      0.88      0.92      1000
#            8       0.94      0.92      0.93      1000
#            9       0.88      0.96      0.92      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# Now test neural network by yourself:

# %%
plt.imshow(test_images[30])

# %%
print("The Image Label: ", class_names[test_labels[30][0]])
# Out:
# The Image Label:  frog

# %%
i = model9.predict_classes(test_images[30].reshape(1,32,32,3))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print("our model predication: ", class_names[i[0]])
# Out:
# our model predication:  frog
